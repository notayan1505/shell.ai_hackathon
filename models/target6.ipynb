# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split

# Feature engineering function (your full version)
def engineer_features_no_pca(df):
    df = df.copy()
    new_cols = {}

    # Weighted component-property features
    for comp in range(1, 6):
        for prop in range(1, 11):
            prop_col = f'Component{comp}_Property{prop}'
            frac_col = f'Component{comp}_fraction'
            new_cols[f'{prop_col}_weighted'] = df[prop_col] * df[frac_col]

    # Interaction features between fractions
    for i in range(1, 6):
        frac_i = f'Component{i}_fraction'
        for j in range(i + 1, 6):
            frac_j = f'Component{j}_fraction'
            new_cols[f'{frac_i}_x_{frac_j}'] = df[frac_i] * df[frac_j]
            new_cols[f'{frac_i}_div_{frac_j}'] = df[frac_i] / (df[frac_j] + 1e-8)

    # Ratios to total fraction
    total_fraction = sum(df[f'Component{i}_fraction'] for i in range(1, 6))
    new_cols['Total_fraction'] = total_fraction
    for i in range(1, 6):
        frac_col = f'Component{i}_fraction'
        new_cols[f'{frac_col}_to_total'] = df[frac_col] / (total_fraction + 1e-8)

    # Aggregate stats for component properties
    for comp in range(1, 6):
        props = [f'Component{comp}_Property{p}' for p in range(1, 11)]
        new_cols[f'Component{comp}_prop_mean'] = df[props].mean(axis=1)
        new_cols[f'Component{comp}_prop_std'] = df[props].std(axis=1)
        new_cols[f'Component{comp}_prop_min'] = df[props].min(axis=1)
        new_cols[f'Component{comp}_prop_max'] = df[props].max(axis=1)
        new_cols[f'Component{comp}_prop_range'] = new_cols[f'Component{comp}_prop_max'] - new_cols[f'Component{comp}_prop_min']

    # Polynomial features for component fractions (squares)
    for i in range(1, 6):
        frac_col = f'Component{i}_fraction'
        new_cols[f'{frac_col}_squared'] = df[frac_col] ** 2

    # Cross product polynomial features
    for i in range(1, 6):
        frac_i = f'Component{i}_fraction'
        for j in range(i + 1, 6):
            frac_j = f'Component{j}_fraction'
            new_cols[f'{frac_i}_x_{frac_j}'] = df[frac_i] * df[frac_j]

    new_features_df = pd.DataFrame(new_cols, index=df.index)
    df = pd.concat([df, new_features_df], axis=1)
    return df

# Load data
X = pd.read_csv('/Users/xDAyN/Desktop/cs project/Project Shell.ai Hackathon/dataset/X_train.csv')
y = pd.read_csv('/Users/xDAyN/Desktop/cs project/Project Shell.ai Hackathon/dataset/y_train.csv')

# Feature engineering
X_fe = engineer_features_no_pca(X)

# Train/validation split
X_train, X_val, y_train, y_val = train_test_split(X_fe, y, test_size=0.2, random_state=42)

target_index = 5  # Target 6 (zero-based indexing)

# Define and train model
model = xgb.XGBRegressor(
    max_depth=1,
    n_estimators=100000,
    learning_rate=0.05,
    reg_alpha=1.5,
    reg_lambda=9,
    eval_metric='mae',
    random_state=42,
    early_stopping_rounds=50,
    verbosity=1
)

print(f"Training model for target {target_index + 1}...")
model.fit(
    X_train, y_train.iloc[:, target_index],
    eval_set=[(X_val, y_val.iloc[:, target_index])],
    verbose=50
)

# Predictions
train_preds = model.predict(X_train)
val_preds = model.predict(X_val)

# Metrics
train_mae = mean_absolute_error(y_train.iloc[:, target_index], train_preds)
val_mae = mean_absolute_error(y_val.iloc[:, target_index], val_preds)

train_mape = mean_absolute_percentage_error(y_train.iloc[:, target_index], train_preds)
val_mape = mean_absolute_percentage_error(y_val.iloc[:, target_index], val_preds)

print(f"\nTrain MAE: {train_mae:.5f}")
print(f"Validation MAE: {val_mae:.5f}")
print(f"Train MAPE: {train_mape:.5f}")
print(f"Validation MAPE: {val_mape:.5f}")

# Feature importance by total gain
booster = model.get_booster()
importance = booster.get_score(importance_type='total_gain')

importance_df = pd.DataFrame({
    'feature': list(importance.keys()),
    'total_gain': list(importance.values())
}).sort_values(by='total_gain', ascending=False)

print("\nTop 20 features by total gain:")
print(importance_df.head(20).reset_index(drop=True))

# Load test set
X_test = pd.read_csv('/Users/xDAyN/Desktop/cs project/Project Shell.ai Hackathon/dataset/X_test.csv')
X_test_fe = engineer_features_no_pca(X_test)

# --- Training and evaluation code (unchanged) ---

print(f"Training model for target {target_index + 1}...")
model.fit(
    X_train, y_train.iloc[:, target_index],
    eval_set=[(X_val, y_val.iloc[:, target_index])],
    verbose=50
)

# Predictions
train_preds = model.predict(X_train)
val_preds = model.predict(X_val)

# Metrics
train_mae = mean_absolute_error(y_train.iloc[:, target_index], train_preds)
val_mae = mean_absolute_error(y_val.iloc[:, target_index], val_preds)

train_mape = mean_absolute_percentage_error(y_train.iloc[:, target_index], train_preds)
val_mape = mean_absolute_percentage_error(y_val.iloc[:, target_index], val_preds)

print(f"\nTrain MAE: {train_mae:.5f}")
print(f"Validation MAE: {val_mae:.5f}")
print(f"Train MAPE: {train_mape:.5f}")
print(f"Validation MAPE: {val_mape:.5f}")

# Feature importance by total gain
booster = model.get_booster()
importance = booster.get_score(importance_type='total_gain')

importance_df = pd.DataFrame({
    'feature': list(importance.keys()),
    'total_gain': list(importance.values())
}).sort_values(by='total_gain', ascending=False)

print("\nTop 20 features by total gain:")
print(importance_df.head(20).reset_index(drop=True))

# --- Predict on test set and save ---
test_preds = model.predict(X_test_fe)
test_output = pd.DataFrame(test_preds, columns=[f'Target{target_index + 1}_prediction'])
test_output.to_csv(f'test_predictions_target_{target_index + 1}.csv', index=False)

print(f"\nTest predictions saved to 'test_predictions_target_{target_index + 1}.csv'")
# Out:
# Training model for target 6...
# [0]	validation_0-mae:0.77556
# [50]	validation_0-mae:0.55456
# [100]	validation_0-mae:0.44945
# [150]	validation_0-mae:0.37960
# [200]	validation_0-mae:0.33237
# [250]	validation_0-mae:0.29789
# [300]	validation_0-mae:0.27230
# [350]	validation_0-mae:0.25118
# [400]	validation_0-mae:0.23385
# [450]	validation_0-mae:0.21856
# [500]	validation_0-mae:0.20576
# [550]	validation_0-mae:0.19542
# [600]	validation_0-mae:0.18699
# [650]	validation_0-mae:0.17987
# [700]	validation_0-mae:0.17364
# [750]	validation_0-mae:0.16873
# [800]	validation_0-mae:0.16418
# [850]	validation_0-mae:0.16002
# [900]	validation_0-mae:0.15637
# [950]	validation_0-mae:0.15323
# [1000]	validation_0-mae:0.15041
# [1050]	validation_0-mae:0.14767
# [1100]	validation_0-mae:0.14513
# [1150]	validation_0-mae:0.14294
# [1200]	validation_0-mae:0.14075
# [1250]	validation_0-mae:0.13864
# [1300]	validation_0-mae:0.13665
# [1350]	validation_0-mae:0.13474
# [1400]	validation_0-mae:0.13288
# [1450]	validation_0-mae:0.13122
# [1500]	validation_0-mae:0.12962
# [1550]	validation_0-mae:0.12819
# [1600]	validation_0-mae:0.12689
# [1650]	validation_0-mae:0.12552
# [1700]	validation_0-mae:0.12437
# [1750]	validation_0-mae:0.12341
# [1800]	validation_0-mae:0.12238
# [1850]	validation_0-mae:0.12142
# [1900]	validation_0-mae:0.12033
# [1950]	validation_0-mae:0.11955
# [2000]	validation_0-mae:0.11860
# [2050]	validation_0-mae:0.11767
# [2100]	validation_0-mae:0.11689
# [2150]	validation_0-mae:0.11622
# [2200]	validation_0-mae:0.11546
# [2250]	validation_0-mae:0.11471
# [2300]	validation_0-mae:0.11410
# [2350]	validation_0-mae:0.11350
# [2400]	validation_0-mae:0.11290
# [2450]	validation_0-mae:0.11227
# [2500]	validation_0-mae:0.11177
# [2550]	validation_0-mae:0.11111
# [2600]	validation_0-mae:0.11070
# [2650]	validation_0-mae:0.11015
# [2700]	validation_0-mae:0.10971
# [2750]	validation_0-mae:0.10917
# [2800]	validation_0-mae:0.10873
# [2850]	validation_0-mae:0.10825
# [2900]	validation_0-mae:0.10784
# [2950]	validation_0-mae:0.10745
# [3000]	validation_0-mae:0.10701
# [3050]	validation_0-mae:0.10663
# [3100]	validation_0-mae:0.10625
# [3150]	validation_0-mae:0.10583
# [3200]	validation_0-mae:0.10554
# [3250]	validation_0-mae:0.10514
# [3300]	validation_0-mae:0.10480
# [3350]	validation_0-mae:0.10448
# [3400]	validation_0-mae:0.10409
# [3450]	validation_0-mae:0.10386
# [3500]	validation_0-mae:0.10355
# [3550]	validation_0-mae:0.10325
# [3600]	validation_0-mae:0.10298
# [3650]	validation_0-mae:0.10273
# [3700]	validation_0-mae:0.10245
# [3750]	validation_0-mae:0.10221
# [3800]	validation_0-mae:0.10198
# [3850]	validation_0-mae:0.10169
# [3900]	validation_0-mae:0.10144
# [3950]	validation_0-mae:0.10118
# [4000]	validation_0-mae:0.10092
# [4050]	validation_0-mae:0.10070
# [4100]	validation_0-mae:0.10049
# [4150]	validation_0-mae:0.10029
# [4200]	validation_0-mae:0.10005
# [4250]	validation_0-mae:0.09986
# [4300]	validation_0-mae:0.09961
# [4350]	validation_0-mae:0.09940
# [4400]	validation_0-mae:0.09921
# [4450]	validation_0-mae:0.09899
# [4500]	validation_0-mae:0.09883
# [4550]	validation_0-mae:0.09863
# [4600]	validation_0-mae:0.09843
# [4650]	validation_0-mae:0.09822
# [4700]	validation_0-mae:0.09804
# [4750]	validation_0-mae:0.09788
# [4800]	validation_0-mae:0.09775
# [4850]	validation_0-mae:0.09760
# [4900]	validation_0-mae:0.09740
# [4950]	validation_0-mae:0.09724
# [5000]	validation_0-mae:0.09711
# [5050]	validation_0-mae:0.09697
# [5100]	validation_0-mae:0.09681
# [5150]	validation_0-mae:0.09670
# [5200]	validation_0-mae:0.09651
# [5250]	validation_0-mae:0.09639
# [5300]	validation_0-mae:0.09631
# [5350]	validation_0-mae:0.09616
# [5400]	validation_0-mae:0.09601
# [5450]	validation_0-mae:0.09597
# [5500]	validation_0-mae:0.09584
# [5550]	validation_0-mae:0.09570
# [5600]	validation_0-mae:0.09559
# [5650]	validation_0-mae:0.09548
# [5700]	validation_0-mae:0.09540
# [5750]	validation_0-mae:0.09526
# [5800]	validation_0-mae:0.09517
# [5850]	validation_0-mae:0.09505
# [5900]	validation_0-mae:0.09501
# [5950]	validation_0-mae:0.09491
# [6000]	validation_0-mae:0.09482
# [6050]	validation_0-mae:0.09475
# [6100]	validation_0-mae:0.09463
# [6150]	validation_0-mae:0.09457
# [6200]	validation_0-mae:0.09447
# [6250]	validation_0-mae:0.09442
# [6300]	validation_0-mae:0.09433
# [6350]	validation_0-mae:0.09425
# [6400]	validation_0-mae:0.09416
# [6450]	validation_0-mae:0.09409
# [6500]	validation_0-mae:0.09401
# [6550]	validation_0-mae:0.09395
# [6600]	validation_0-mae:0.09388
# [6650]	validation_0-mae:0.09380
# [6700]	validation_0-mae:0.09373
# [6750]	validation_0-mae:0.09368
# [6800]	validation_0-mae:0.09362
# [6850]	validation_0-mae:0.09354
# [6900]	validation_0-mae:0.09346
# [6950]	validation_0-mae:0.09339
# [7000]	validation_0-mae:0.09334
# [7050]	validation_0-mae:0.09327
# [7100]	validation_0-mae:0.09320
# [7150]	validation_0-mae:0.09316
# [7200]	validation_0-mae:0.09308
# [7250]	validation_0-mae:0.09304
# [7300]	validation_0-mae:0.09297
# [7350]	validation_0-mae:0.09290
# [7400]	validation_0-mae:0.09286
# [7450]	validation_0-mae:0.09280
# [7500]	validation_0-mae:0.09276
# [7550]	validation_0-mae:0.09270
# [7600]	validation_0-mae:0.09266
# [7650]	validation_0-mae:0.09259
# [7700]	validation_0-mae:0.09254
# [7750]	validation_0-mae:0.09250
# [7800]	validation_0-mae:0.09244
# [7850]	validation_0-mae:0.09238
# [7900]	validation_0-mae:0.09233
# [7950]	validation_0-mae:0.09228
# [8000]	validation_0-mae:0.09224
# [8050]	validation_0-mae:0.09219
# [8100]	validation_0-mae:0.09217
# [8150]	validation_0-mae:0.09210
# [8200]	validation_0-mae:0.09206
# [8250]	validation_0-mae:0.09203
# [8300]	validation_0-mae:0.09197
# [8350]	validation_0-mae:0.09193
# [8400]	validation_0-mae:0.09188
# [8450]	validation_0-mae:0.09186
# [8500]	validation_0-mae:0.09182
# [8550]	validation_0-mae:0.09177
# [8600]	validation_0-mae:0.09171
# [8650]	validation_0-mae:0.09169
# [8700]	validation_0-mae:0.09166
# [8750]	validation_0-mae:0.09161
# [8800]	validation_0-mae:0.09157
# [8850]	validation_0-mae:0.09153
# [8900]	validation_0-mae:0.09152
# [8950]	validation_0-mae:0.09148
# [9000]	validation_0-mae:0.09145
# [9050]	validation_0-mae:0.09141
# [9100]	validation_0-mae:0.09137
# [9150]	validation_0-mae:0.09134
# [9200]	validation_0-mae:0.09131
# [9250]	validation_0-mae:0.09127
# [9300]	validation_0-mae:0.09124
# [9350]	validation_0-mae:0.09120
# [9400]	validation_0-mae:0.09117
# [9450]	validation_0-mae:0.09113
# [9500]	validation_0-mae:0.09112
# [9550]	validation_0-mae:0.09107
# [9600]	validation_0-mae:0.09104
# [9650]	validation_0-mae:0.09102
# [9700]	validation_0-mae:0.09098
# [9750]	validation_0-mae:0.09095
# [9800]	validation_0-mae:0.09092
# [9850]	validation_0-mae:0.09088
# [9900]	validation_0-mae:0.09087
# [9950]	validation_0-mae:0.09083
# [10000]	validation_0-mae:0.09080
# [10050]	validation_0-mae:0.09078
# [10100]	validation_0-mae:0.09074
# [10150]	validation_0-mae:0.09070
# [10200]	validation_0-mae:0.09068
# [10250]	validation_0-mae:0.09066
# [10300]	validation_0-mae:0.09063
# [10350]	validation_0-mae:0.09060
# [10400]	validation_0-mae:0.09057
# [10450]	validation_0-mae:0.09055
# [10500]	validation_0-mae:0.09051
# [10550]	validation_0-mae:0.09049
# [10600]	validation_0-mae:0.09046
# [10650]	validation_0-mae:0.09044
# [10700]	validation_0-mae:0.09042
# [10750]	validation_0-mae:0.09040
# [10800]	validation_0-mae:0.09037
# [10850]	validation_0-mae:0.09033
# [10900]	validation_0-mae:0.09030
# [10950]	validation_0-mae:0.09028
# [11000]	validation_0-mae:0.09027
# [11050]	validation_0-mae:0.09025
# [11100]	validation_0-mae:0.09022
# [11150]	validation_0-mae:0.09020
# [11200]	validation_0-mae:0.09018
# [11250]	validation_0-mae:0.09015
# [11300]	validation_0-mae:0.09013
# [11350]	validation_0-mae:0.09011
# [11400]	validation_0-mae:0.09009
# [11450]	validation_0-mae:0.09007
# [11500]	validation_0-mae:0.09006
# [11550]	validation_0-mae:0.09003
# [11600]	validation_0-mae:0.09001
# [11650]	validation_0-mae:0.08998
# [11700]	validation_0-mae:0.08997
# [11750]	validation_0-mae:0.08994
# [11800]	validation_0-mae:0.08993
# [11850]	validation_0-mae:0.08991
# [11900]	validation_0-mae:0.08988
# [11950]	validation_0-mae:0.08986
# [12000]	validation_0-mae:0.08984
# [12050]	validation_0-mae:0.08983
# [12100]	validation_0-mae:0.08980
# [12150]	validation_0-mae:0.08979
# [12200]	validation_0-mae:0.08977
# [12250]	validation_0-mae:0.08974
# [12300]	validation_0-mae:0.08972
# [12350]	validation_0-mae:0.08971
# [12400]	validation_0-mae:0.08969
# [12450]	validation_0-mae:0.08967
# [12500]	validation_0-mae:0.08965
# [12550]	validation_0-mae:0.08964
# [12600]	validation_0-mae:0.08962
# [12650]	validation_0-mae:0.08961
# [12700]	validation_0-mae:0.08958
# [12750]	validation_0-mae:0.08957
# [12800]	validation_0-mae:0.08955
# [12850]	validation_0-mae:0.08955
# [12900]	validation_0-mae:0.08953
# [12950]	validation_0-mae:0.08951
# [13000]	validation_0-mae:0.08949
# [13050]	validation_0-mae:0.08948
# [13100]	validation_0-mae:0.08947
# [13150]	validation_0-mae:0.08945
# [13200]	validation_0-mae:0.08943
# [13250]	validation_0-mae:0.08942
# [13300]	validation_0-mae:0.08940
# [13350]	validation_0-mae:0.08939
# [13400]	validation_0-mae:0.08938
# [13450]	validation_0-mae:0.08937
# [13500]	validation_0-mae:0.08934
# [13550]	validation_0-mae:0.08933
# [13600]	validation_0-mae:0.08932
# [13650]	validation_0-mae:0.08931
# [13700]	validation_0-mae:0.08929
# [13750]	validation_0-mae:0.08927
# [13800]	validation_0-mae:0.08927
# [13850]	validation_0-mae:0.08926
# [13900]	validation_0-mae:0.08925
# [13950]	validation_0-mae:0.08924
# [14000]	validation_0-mae:0.08922
# [14050]	validation_0-mae:0.08921
# [14100]	validation_0-mae:0.08920
# [14150]	validation_0-mae:0.08918
# [14200]	validation_0-mae:0.08917
# [14250]	validation_0-mae:0.08916
# [14300]	validation_0-mae:0.08915
# [14350]	validation_0-mae:0.08914
# [14400]	validation_0-mae:0.08912
# [14450]	validation_0-mae:0.08911
# [14500]	validation_0-mae:0.08909
# [14550]	validation_0-mae:0.08908
# [14600]	validation_0-mae:0.08907
# [14650]	validation_0-mae:0.08906
# [14700]	validation_0-mae:0.08905
# [14750]	validation_0-mae:0.08904
# [14800]	validation_0-mae:0.08903
# [14850]	validation_0-mae:0.08902
# [14900]	validation_0-mae:0.08900
# [14950]	validation_0-mae:0.08900
# [15000]	validation_0-mae:0.08899
# [15050]	validation_0-mae:0.08898
# [15100]	validation_0-mae:0.08897
# [15150]	validation_0-mae:0.08896
# [15200]	validation_0-mae:0.08895
# [15250]	validation_0-mae:0.08894
# [15300]	validation_0-mae:0.08892
# [15350]	validation_0-mae:0.08891
# [15400]	validation_0-mae:0.08890
# [15450]	validation_0-mae:0.08890
# [15500]	validation_0-mae:0.08888
# [15550]	validation_0-mae:0.08887
# [15600]	validation_0-mae:0.08886
# [15650]	validation_0-mae:0.08886
# [15700]	validation_0-mae:0.08885
# [15750]	validation_0-mae:0.08884
# [15800]	validation_0-mae:0.08883
# [15850]	validation_0-mae:0.08882
# [15900]	validation_0-mae:0.08881
# [15950]	validation_0-mae:0.08880
# [16000]	validation_0-mae:0.08880
# [16050]	validation_0-mae:0.08879
# [16100]	validation_0-mae:0.08878
# [16150]	validation_0-mae:0.08877
# [16200]	validation_0-mae:0.08876
# [16250]	validation_0-mae:0.08875
# [16300]	validation_0-mae:0.08875
# [16350]	validation_0-mae:0.08874
# [16400]	validation_0-mae:0.08873
# [16450]	validation_0-mae:0.08872
# [16500]	validation_0-mae:0.08871
# [16550]	validation_0-mae:0.08871
# [16600]	validation_0-mae:0.08869
# [16650]	validation_0-mae:0.08869
# [16700]	validation_0-mae:0.08868
# [16750]	validation_0-mae:0.08867
# [16800]	validation_0-mae:0.08866
# [16850]	validation_0-mae:0.08865
# [16900]	validation_0-mae:0.08864
# [16950]	validation_0-mae:0.08863
# [17000]	validation_0-mae:0.08863
# [17050]	validation_0-mae:0.08862
# [17100]	validation_0-mae:0.08861
# [17150]	validation_0-mae:0.08860
# [17200]	validation_0-mae:0.08860
# [17250]	validation_0-mae:0.08859
# [17300]	validation_0-mae:0.08858
# [17350]	validation_0-mae:0.08857
# [17400]	validation_0-mae:0.08857
# [17450]	validation_0-mae:0.08856
# [17500]	validation_0-mae:0.08855
# [17550]	validation_0-mae:0.08855
# [17600]	validation_0-mae:0.08854
# [17650]	validation_0-mae:0.08853
# [17700]	validation_0-mae:0.08852
# [17750]	validation_0-mae:0.08852
# [17800]	validation_0-mae:0.08851
# [17850]	validation_0-mae:0.08850
# [17900]	validation_0-mae:0.08849
# [17950]	validation_0-mae:0.08849
# [18000]	validation_0-mae:0.08848
# [18050]	validation_0-mae:0.08848
# [18100]	validation_0-mae:0.08847
# [18150]	validation_0-mae:0.08846
# [18200]	validation_0-mae:0.08846
# [18206]	validation_0-mae:0.08846
#
# Train MAE: 0.05480
# Validation MAE: 0.08846
# Train MAPE: 0.21195
# Validation MAPE: 0.53652
#
# Top 20 features by total gain:
#                                         feature   total_gain
# 0   Component2_fraction_div_Component5_fraction  2856.975098
# 1                 Component3_Property6_weighted  2531.396484
# 2                 Component4_Property6_weighted  2530.019775
# 3                           Component5_fraction  1859.778320
# 4                 Component1_Property6_weighted  1094.078491
# 5     Component3_fraction_x_Component5_fraction  1083.188721
# 6                 Component2_Property6_weighted  1079.528687
# 7     Component4_fraction_x_Component5_fraction  1070.459229
# 8                 Component5_Property6_weighted   891.567993
# 9                          Component4_Property6   380.316986
# 10                          Component2_fraction   319.128998
# 11  Component2_fraction_div_Component4_fraction    90.195923
# 12                         Component2_Property6    83.188797
# 13                         Component5_Property6    79.386559
# 14                         Component3_Property6    76.356628
# 15  Component1_fraction_div_Component5_fraction    60.840206
# 16    Component3_fraction_x_Component4_fraction    45.635780
# 17  Component4_fraction_div_Component5_fraction    27.649252
# 18                          Component3_fraction    22.018404
# 19                          Component4_fraction    15.613759
# Training model for target 6...
# [0]	validation_0-mae:0.77556
# [50]	validation_0-mae:0.55456
# [100]	validation_0-mae:0.44945
# [150]	validation_0-mae:0.37960
# [200]	validation_0-mae:0.33237
# [250]	validation_0-mae:0.29789
# [300]	validation_0-mae:0.27230
# [350]	validation_0-mae:0.25118
# [400]	validation_0-mae:0.23385
# [450]	validation_0-mae:0.21856
# [500]	validation_0-mae:0.20576
# [550]	validation_0-mae:0.19542
# [600]	validation_0-mae:0.18699
# [650]	validation_0-mae:0.17987
# [700]	validation_0-mae:0.17364
# [750]	validation_0-mae:0.16873
# [800]	validation_0-mae:0.16418
# [850]	validation_0-mae:0.16002
# [900]	validation_0-mae:0.15637
# [950]	validation_0-mae:0.15323
# [1000]	validation_0-mae:0.15041
# [1050]	validation_0-mae:0.14767
# [1100]	validation_0-mae:0.14513
# [1150]	validation_0-mae:0.14294
# [1200]	validation_0-mae:0.14075
# [1250]	validation_0-mae:0.13864
# [1300]	validation_0-mae:0.13665
# [1350]	validation_0-mae:0.13474
# [1400]	validation_0-mae:0.13288
# [1450]	validation_0-mae:0.13122
# [1500]	validation_0-mae:0.12962
# [1550]	validation_0-mae:0.12819
# [1600]	validation_0-mae:0.12689
# [1650]	validation_0-mae:0.12552
# [1700]	validation_0-mae:0.12437
# [1750]	validation_0-mae:0.12341
# [1800]	validation_0-mae:0.12238
# [1850]	validation_0-mae:0.12142
# [1900]	validation_0-mae:0.12033
# [1950]	validation_0-mae:0.11955
# [2000]	validation_0-mae:0.11860
# [2050]	validation_0-mae:0.11767
# [2100]	validation_0-mae:0.11689
# [2150]	validation_0-mae:0.11622
# [2200]	validation_0-mae:0.11546
# [2250]	validation_0-mae:0.11471
# [2300]	validation_0-mae:0.11410
# [2350]	validation_0-mae:0.11350
# [2400]	validation_0-mae:0.11290
# [2450]	validation_0-mae:0.11227
# [2500]	validation_0-mae:0.11177
# [2550]	validation_0-mae:0.11111
# [2600]	validation_0-mae:0.11070
# [2650]	validation_0-mae:0.11015
# [2700]	validation_0-mae:0.10971
# [2750]	validation_0-mae:0.10917
# [2800]	validation_0-mae:0.10873
# [2850]	validation_0-mae:0.10825
# [2900]	validation_0-mae:0.10784
# [2950]	validation_0-mae:0.10745
# [3000]	validation_0-mae:0.10701
# [3050]	validation_0-mae:0.10663
# [3100]	validation_0-mae:0.10625
# [3150]	validation_0-mae:0.10583
# [3200]	validation_0-mae:0.10554
# [3250]	validation_0-mae:0.10514
# [3300]	validation_0-mae:0.10480
# [3350]	validation_0-mae:0.10448
# [3400]	validation_0-mae:0.10409
# [3450]	validation_0-mae:0.10386
# [3500]	validation_0-mae:0.10355
# [3550]	validation_0-mae:0.10325
# [3600]	validation_0-mae:0.10298
# [3650]	validation_0-mae:0.10273
# [3700]	validation_0-mae:0.10245
# [3750]	validation_0-mae:0.10221
# [3800]	validation_0-mae:0.10198
# [3850]	validation_0-mae:0.10169
# [3900]	validation_0-mae:0.10144
# [3950]	validation_0-mae:0.10118
# [4000]	validation_0-mae:0.10092
# [4050]	validation_0-mae:0.10070
# [4100]	validation_0-mae:0.10049
# [4150]	validation_0-mae:0.10029
# [4200]	validation_0-mae:0.10005
# [4250]	validation_0-mae:0.09986
# [4300]	validation_0-mae:0.09961
# [4350]	validation_0-mae:0.09940
# [4400]	validation_0-mae:0.09921
# [4450]	validation_0-mae:0.09899
# [4500]	validation_0-mae:0.09883
# [4550]	validation_0-mae:0.09863
# [4600]	validation_0-mae:0.09843
# [4650]	validation_0-mae:0.09822
# [4700]	validation_0-mae:0.09804
# [4750]	validation_0-mae:0.09788
# [4800]	validation_0-mae:0.09775
# [4850]	validation_0-mae:0.09760
# [4900]	validation_0-mae:0.09740
# [4950]	validation_0-mae:0.09724
# [5000]	validation_0-mae:0.09711
# [5050]	validation_0-mae:0.09697
# [5100]	validation_0-mae:0.09681
# [5150]	validation_0-mae:0.09670
# [5200]	validation_0-mae:0.09651
# [5250]	validation_0-mae:0.09639
# [5300]	validation_0-mae:0.09631
# [5350]	validation_0-mae:0.09616
# [5400]	validation_0-mae:0.09601
# [5450]	validation_0-mae:0.09597
# [5500]	validation_0-mae:0.09584
# [5550]	validation_0-mae:0.09570
# [5600]	validation_0-mae:0.09559
# [5650]	validation_0-mae:0.09548
# [5700]	validation_0-mae:0.09540
# [5750]	validation_0-mae:0.09526
# [5800]	validation_0-mae:0.09517
# [5850]	validation_0-mae:0.09505
# [5900]	validation_0-mae:0.09501
# [5950]	validation_0-mae:0.09491
# [6000]	validation_0-mae:0.09482
# [6050]	validation_0-mae:0.09475
# [6100]	validation_0-mae:0.09463
# [6150]	validation_0-mae:0.09457
# [6200]	validation_0-mae:0.09447
# [6250]	validation_0-mae:0.09442
# [6300]	validation_0-mae:0.09433
# [6350]	validation_0-mae:0.09425
# [6400]	validation_0-mae:0.09416
# [6450]	validation_0-mae:0.09409
# [6500]	validation_0-mae:0.09401
# [6550]	validation_0-mae:0.09395
# [6600]	validation_0-mae:0.09388
# [6650]	validation_0-mae:0.09380
# [6700]	validation_0-mae:0.09373
# [6750]	validation_0-mae:0.09368
# [6800]	validation_0-mae:0.09362
# [6850]	validation_0-mae:0.09354
# [6900]	validation_0-mae:0.09346
# [6950]	validation_0-mae:0.09339
# [7000]	validation_0-mae:0.09334
# [7050]	validation_0-mae:0.09327
# [7100]	validation_0-mae:0.09320
# [7150]	validation_0-mae:0.09316
# [7200]	validation_0-mae:0.09308
# [7250]	validation_0-mae:0.09304
# [7300]	validation_0-mae:0.09297
# [7350]	validation_0-mae:0.09290
# [7400]	validation_0-mae:0.09286
# [7450]	validation_0-mae:0.09280
# [7500]	validation_0-mae:0.09276
# [7550]	validation_0-mae:0.09270
# [7600]	validation_0-mae:0.09266
# [7650]	validation_0-mae:0.09259
# [7700]	validation_0-mae:0.09254
# [7750]	validation_0-mae:0.09250
# [7800]	validation_0-mae:0.09244
# [7850]	validation_0-mae:0.09238
# [7900]	validation_0-mae:0.09233
# [7950]	validation_0-mae:0.09228
# [8000]	validation_0-mae:0.09224
# [8050]	validation_0-mae:0.09219
# [8100]	validation_0-mae:0.09217
# [8150]	validation_0-mae:0.09210
# [8200]	validation_0-mae:0.09206
# [8250]	validation_0-mae:0.09203
# [8300]	validation_0-mae:0.09197
# [8350]	validation_0-mae:0.09193
# [8400]	validation_0-mae:0.09188
# [8450]	validation_0-mae:0.09186
# [8500]	validation_0-mae:0.09182
# [8550]	validation_0-mae:0.09177
# [8600]	validation_0-mae:0.09171
# [8650]	validation_0-mae:0.09169
# [8700]	validation_0-mae:0.09166
# [8750]	validation_0-mae:0.09161
# [8800]	validation_0-mae:0.09157
# [8850]	validation_0-mae:0.09153
# [8900]	validation_0-mae:0.09152
# [8950]	validation_0-mae:0.09148
# [9000]	validation_0-mae:0.09145
# [9050]	validation_0-mae:0.09141
# [9100]	validation_0-mae:0.09137
# [9150]	validation_0-mae:0.09134
# [9200]	validation_0-mae:0.09131
# [9250]	validation_0-mae:0.09127
# [9300]	validation_0-mae:0.09124
# [9350]	validation_0-mae:0.09120
# [9400]	validation_0-mae:0.09117
# [9450]	validation_0-mae:0.09113
# [9500]	validation_0-mae:0.09112
# [9550]	validation_0-mae:0.09107
# [9600]	validation_0-mae:0.09104
# [9650]	validation_0-mae:0.09102
# [9700]	validation_0-mae:0.09098
# [9750]	validation_0-mae:0.09095
# [9800]	validation_0-mae:0.09092
# [9850]	validation_0-mae:0.09088
# [9900]	validation_0-mae:0.09087
# [9950]	validation_0-mae:0.09083
# [10000]	validation_0-mae:0.09080
# [10050]	validation_0-mae:0.09078
# [10100]	validation_0-mae:0.09074
# [10150]	validation_0-mae:0.09070
# [10200]	validation_0-mae:0.09068
# [10250]	validation_0-mae:0.09066
# [10300]	validation_0-mae:0.09063
# [10350]	validation_0-mae:0.09060
# [10400]	validation_0-mae:0.09057
# [10450]	validation_0-mae:0.09055
# [10500]	validation_0-mae:0.09051
# [10550]	validation_0-mae:0.09049
# [10600]	validation_0-mae:0.09046
# [10650]	validation_0-mae:0.09044
# [10700]	validation_0-mae:0.09042
# [10750]	validation_0-mae:0.09040
# [10800]	validation_0-mae:0.09037
# [10850]	validation_0-mae:0.09033
# [10900]	validation_0-mae:0.09030
# [10950]	validation_0-mae:0.09028
# [11000]	validation_0-mae:0.09027
# [11050]	validation_0-mae:0.09025
# [11100]	validation_0-mae:0.09022
# [11150]	validation_0-mae:0.09020
# [11200]	validation_0-mae:0.09018
# [11250]	validation_0-mae:0.09015
# [11300]	validation_0-mae:0.09013
# [11350]	validation_0-mae:0.09011
# [11400]	validation_0-mae:0.09009
# [11450]	validation_0-mae:0.09007
# [11500]	validation_0-mae:0.09006
# [11550]	validation_0-mae:0.09003
# [11600]	validation_0-mae:0.09001
# [11650]	validation_0-mae:0.08998
# [11700]	validation_0-mae:0.08997
# [11750]	validation_0-mae:0.08994
# [11800]	validation_0-mae:0.08993
# [11850]	validation_0-mae:0.08991
# [11900]	validation_0-mae:0.08988
# [11950]	validation_0-mae:0.08986
# [12000]	validation_0-mae:0.08984
# [12050]	validation_0-mae:0.08983
# [12100]	validation_0-mae:0.08980
# [12150]	validation_0-mae:0.08979
# [12200]	validation_0-mae:0.08977
# [12250]	validation_0-mae:0.08974
# [12300]	validation_0-mae:0.08972
# [12350]	validation_0-mae:0.08971
# [12400]	validation_0-mae:0.08969
# [12450]	validation_0-mae:0.08967
# [12500]	validation_0-mae:0.08965
# [12550]	validation_0-mae:0.08964
# [12600]	validation_0-mae:0.08962
# [12650]	validation_0-mae:0.08961
# [12700]	validation_0-mae:0.08958
# [12750]	validation_0-mae:0.08957
# [12800]	validation_0-mae:0.08955
# [12850]	validation_0-mae:0.08955
# [12900]	validation_0-mae:0.08953
# [12950]	validation_0-mae:0.08951
# [13000]	validation_0-mae:0.08949
# [13050]	validation_0-mae:0.08948
# [13100]	validation_0-mae:0.08947
# [13150]	validation_0-mae:0.08945
# [13200]	validation_0-mae:0.08943
# [13250]	validation_0-mae:0.08942
# [13300]	validation_0-mae:0.08940
# [13350]	validation_0-mae:0.08939
# [13400]	validation_0-mae:0.08938
# [13450]	validation_0-mae:0.08937
# [13500]	validation_0-mae:0.08934
# [13550]	validation_0-mae:0.08933
# [13600]	validation_0-mae:0.08932
# [13650]	validation_0-mae:0.08931
# [13700]	validation_0-mae:0.08929
# [13750]	validation_0-mae:0.08927
# [13800]	validation_0-mae:0.08927
# [13850]	validation_0-mae:0.08926
# [13900]	validation_0-mae:0.08925
# [13950]	validation_0-mae:0.08924
# [14000]	validation_0-mae:0.08922
# [14050]	validation_0-mae:0.08921
# [14100]	validation_0-mae:0.08920
# [14150]	validation_0-mae:0.08918
# [14200]	validation_0-mae:0.08917
# [14250]	validation_0-mae:0.08916
# [14300]	validation_0-mae:0.08915
# [14350]	validation_0-mae:0.08914
# [14400]	validation_0-mae:0.08912
# [14450]	validation_0-mae:0.08911
# [14500]	validation_0-mae:0.08909
# [14550]	validation_0-mae:0.08908
# [14600]	validation_0-mae:0.08907
# [14650]	validation_0-mae:0.08906
# [14700]	validation_0-mae:0.08905
# [14750]	validation_0-mae:0.08904
# [14800]	validation_0-mae:0.08903
# [14850]	validation_0-mae:0.08902
# [14900]	validation_0-mae:0.08900
# [14950]	validation_0-mae:0.08900
# [15000]	validation_0-mae:0.08899
# [15050]	validation_0-mae:0.08898
# [15100]	validation_0-mae:0.08897
# [15150]	validation_0-mae:0.08896
# [15200]	validation_0-mae:0.08895
# [15250]	validation_0-mae:0.08894
# [15300]	validation_0-mae:0.08892
# [15350]	validation_0-mae:0.08891
# [15400]	validation_0-mae:0.08890
# [15450]	validation_0-mae:0.08890
# [15500]	validation_0-mae:0.08888
# [15550]	validation_0-mae:0.08887
# [15600]	validation_0-mae:0.08886
# [15650]	validation_0-mae:0.08886
# [15700]	validation_0-mae:0.08885
# [15750]	validation_0-mae:0.08884
# [15800]	validation_0-mae:0.08883
# [15850]	validation_0-mae:0.08882
# [15900]	validation_0-mae:0.08881
# [15950]	validation_0-mae:0.08880
# [16000]	validation_0-mae:0.08880
# [16050]	validation_0-mae:0.08879
# [16100]	validation_0-mae:0.08878
# [16150]	validation_0-mae:0.08877
# [16200]	validation_0-mae:0.08876
# [16250]	validation_0-mae:0.08875
# [16300]	validation_0-mae:0.08875
# [16350]	validation_0-mae:0.08874
# [16400]	validation_0-mae:0.08873
# [16450]	validation_0-mae:0.08872
# [16500]	validation_0-mae:0.08871
# [16550]	validation_0-mae:0.08871
# [16600]	validation_0-mae:0.08869
# [16650]	validation_0-mae:0.08869
# [16700]	validation_0-mae:0.08868
# [16750]	validation_0-mae:0.08867
# [16800]	validation_0-mae:0.08866
# [16850]	validation_0-mae:0.08865
# [16900]	validation_0-mae:0.08864
# [16950]	validation_0-mae:0.08863
# [17000]	validation_0-mae:0.08863
# [17050]	validation_0-mae:0.08862
# [17100]	validation_0-mae:0.08861
# [17150]	validation_0-mae:0.08860
# [17200]	validation_0-mae:0.08860
# [17250]	validation_0-mae:0.08859
# [17300]	validation_0-mae:0.08858
# [17350]	validation_0-mae:0.08857
# [17400]	validation_0-mae:0.08857
# [17450]	validation_0-mae:0.08856
# [17500]	validation_0-mae:0.08855
# [17550]	validation_0-mae:0.08855
# [17600]	validation_0-mae:0.08854
# [17650]	validation_0-mae:0.08853
# [17700]	validation_0-mae:0.08852
# [17750]	validation_0-mae:0.08852
# [17800]	validation_0-mae:0.08851
# [17850]	validation_0-mae:0.08850
# [17900]	validation_0-mae:0.08849
# [17950]	validation_0-mae:0.08849
# [18000]	validation_0-mae:0.08848
# [18050]	validation_0-mae:0.08848
# [18100]	validation_0-mae:0.08847
# [18150]	validation_0-mae:0.08846
# [18200]	validation_0-mae:0.08846
# [18206]	validation_0-mae:0.08846
#
# Train MAE: 0.05480
# Validation MAE: 0.08846
# Train MAPE: 0.21195
# Validation MAPE: 0.53652
#
# Top 20 features by total gain:
#                                         feature   total_gain
# 0   Component2_fraction_div_Component5_fraction  2856.975098
# 1                 Component3_Property6_weighted  2531.396484
# 2                 Component4_Property6_weighted  2530.019775
# 3                           Component5_fraction  1859.778320
# 4                 Component1_Property6_weighted  1094.078491
# 5     Component3_fraction_x_Component5_fraction  1083.188721
# 6                 Component2_Property6_weighted  1079.528687
# 7     Component4_fraction_x_Component5_fraction  1070.459229
# 8                 Component5_Property6_weighted   891.567993
# 9                          Component4_Property6   380.316986
# 10                          Component2_fraction   319.128998
# 11  Component2_fraction_div_Component4_fraction    90.195923
# 12                         Component2_Property6    83.188797
# 13                         Component5_Property6    79.386559
# 14                         Component3_Property6    76.356628
# 15  Component1_fraction_div_Component5_fraction    60.840206
# 16    Component3_fraction_x_Component4_fraction    45.635780
# 17  Component4_fraction_div_Component5_fraction    27.649252
# 18                          Component3_fraction    22.018404
# 19                          Component4_fraction    15.613759
#
# Test predictions saved to 'test_predictions_target_6.csv'
